# %%
import pandas as pd

# %%
df = pd.read_csv('datos.csv', delimiter=';', index_col='FECHA')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 01/05/2022 to 31/05/2022
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   idEstacion  62 non-null     int64
#  1   Temp.       44 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.5+ KB

# %%
df.interpolate(method ='linear', limit_direction ='both', inplace=True)

df.head(60)
# Out:
#             idEstacion      Temp.
# FECHA
# 01/05/2022    46250080  16.000000
# 02/05/2022    46250080  24.000000
# 03/05/2022    46250080  27.000000
# 04/05/2022    46250080  20.000000
# 05/05/2022    46250080  24.000000
# 06/05/2022    46250080  28.000000
# 07/05/2022    46250080  15.000000
# 08/05/2022    46250080  20.000000
# 09/05/2022    46250080  25.000000
# 10/05/2022    46250080  30.000000
# 11/05/2022    46250080  30.000000
# 12/05/2022    46250080  25.000000
# 13/05/2022    46250080  25.000000
# 14/05/2022    46250080  27.000000
# 15/05/2022    46250080  24.000000
# 16/05/2022    46250080  21.000000
# 17/05/2022    46250080  28.000000
# 18/05/2022    46250080  28.000000
# 19/05/2022    46250080  26.000000
# 20/05/2022    46250080  24.000000
# 21/05/2022    46250080  26.000000
# 22/05/2022    46250080  29.000000
# 23/05/2022    46250080  18.000000
# 24/05/2022    46250080  22.000000
# 25/05/2022    46250080  30.000000
# 26/05/2022    46250080  28.500000
# ...
