# %%
import pandas as pd
import numpy as np
import os

# %%
'''
# Inicializar entorno de rutas en google drive para carga de archivos 
from google.colab import drive
drive.mount('/content/drive')
'''

# %%
#Nombre del directorio de datos para rutas de ejecucion en ENTORNO LOCAL
PATH_read = "datoscsv_read"
PATH_write = "datoscsv_write"
pathdatos = os.path.join(PATH_read)
pathgraba = os.path.join(PATH_write)

# %%
'''
# cargar dataset con todas las estaciones, definir la fecha como índice del dataframe
df = pd.read_csv('../datoscsv/airWeather_2013-2019inter.csv', sep=';', index_col='FECHA', parse_dates=['FECHA'])

# Volver a recuperar la fecha como campo
df.insert(0, 'FECHA', df.index.strftime('%Y-%m-%d'))
'''

# %%
# cargar dataset con todas las estaciones, definir la fecha como índice del dataframe
df = pd.read_csv('../../datoscsv_read/airWeather_2013-2019inter.csv', sep=';')
'''
# cargar dataset con todas las estaciones, definir la fecha como índice del dataframe
df = pd.read_csv(pathdatos+'/airWeather_2013-2019inter.csv', sep=';')
'''
# Out:
# "\n# cargar dataset con todas las estaciones, definir la fecha como índice del dataframe\ndf = pd.read_csv(pathdatos+'/airWeather_2013-2019inter.csv', sep=';')\n"

# %%
df
# Out:
#             FECHA  COD_ESTACION              NOM_ESTACION  SO2  CO    NO  \
# 0      2013-01-01      46250030  VALÈNCIA  PISTA DE SILLA  NaN NaN   NaN
# 1      2013-01-02      46250030  VALÈNCIA  PISTA DE SILLA  NaN NaN   NaN
# 2      2013-01-03      46250030  VALÈNCIA  PISTA DE SILLA  NaN NaN   NaN
# 3      2013-01-04      46250030  VALÈNCIA  PISTA DE SILLA  NaN NaN   NaN
# 4      2013-01-05      46250030  VALÈNCIA  PISTA DE SILLA  NaN NaN   NaN
# ...           ...           ...                       ...  ...  ..   ...
# 18252  2019-12-27      46250054           VALÈNCIA CENTRE  NaN NaN  38.0
# 18253  2019-12-28      46250054           VALÈNCIA CENTRE  NaN NaN  20.0
# 18254  2019-12-29      46250054           VALÈNCIA CENTRE  NaN NaN   5.0
# 18255  2019-12-30      46250054           VALÈNCIA CENTRE  NaN NaN  28.0
# 18256  2019-12-31      46250054           VALÈNCIA CENTRE  NaN NaN  19.0
#
#         NO2   NOx    O3  PM10  PM2.5  PM1  lluvias   Temp  VelocVent  \
# ...

# %%
df.isnull().sum()/len(df)*100

# %%
# Comprobar rango de fechas disponible para cada estación y registros disponibles
# df['FECHA'] = pd.to_datetime(df['FECHA'], format="%d/%m/%Y")
print(f'Nº de registros totales y rango de fechas por estación:')
print(f'{"COD_ESTACION":=^10}{"NOM_ESTACION":=^30} {"Desde":=^10} {"Hasta":=^10} {"Nº reg":=^8}')
for esta in df['NOM_ESTACION'].unique():
  print(f'{str(df[df["NOM_ESTACION"]==esta]["COD_ESTACION"].unique())[0:10]} {esta:30} {str(df[df["NOM_ESTACION"]==esta]["FECHA"].min())[0:10]} {str(df[df["NOM_ESTACION"]==esta]["FECHA"].max())[0:10]} {df[df["NOM_ESTACION"]==esta]["NOM_ESTACION"].count():8}')

# %%
print(f'Nº de registros totales y nº de atributos nulos por estación:')
print(f'{"NOM_ESTACION":=^26} {"Nº reg":=^6} {"SO2":=^5} {"CO":=^5} {"NO":=^5} {"NO2":=^5} {"NOx":=^5} {"O3":=^5} {"PM10":=^5}\
 {"PM2.5":=^5} {"PM1":=^5} {"lluv":=^5} {"Temp":=^5} {"VVent":=^5} {"VVmax":=^5} {"TempM":=^5} {"Tempm":=^5}')
for esta in df['NOM_ESTACION'].unique():
  print(f'{esta:26} {df[df["NOM_ESTACION"]==esta]["NOM_ESTACION"].count():6}\
 {df[df["NOM_ESTACION"]==esta]["SO2"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["CO"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["NO"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["NO2"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["NOx"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["O3"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["PM10"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["PM2.5"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["PM1"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["lluvias"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["Temp"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["VelocVent"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["VelocVentMax"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["TempMax"].isnull().sum():5}\
 {df[df["NOM_ESTACION"]==esta]["TempMin"].isnull().sum():5}')

print(f'{"TOTAL ESTACIONES:":>26} {df["NOM_ESTACION"].count():6}\
 {df["SO2"].isnull().sum():5}\
 {df["CO"].isnull().sum():5}\
 {df["NO"].isnull().sum():5}\
 {df["NO2"].isnull().sum():5}\
 {df["NOx"].isnull().sum():5}\
 {df["O3"].isnull().sum():5}\
 {df["PM10"].isnull().sum():5}\
 {df["PM2.5"].isnull().sum():5}\
 {df["PM1"].isnull().sum():5}\
 {df["lluvias"].isnull().sum():5}\
 {df["Temp"].isnull().sum():5}\
 {df["VelocVent"].isnull().sum():5}\
 {df["VelocVentMax"].isnull().sum():5}\
 {df["TempMax"].isnull().sum():5}\
 {df["TempMin"].isnull().sum():5}')

# %%
print(f'Nº de registros totales y PORCENTAJE DE atributos nulos por estación:')
print(f'{"NOM_ESTACION":=^26} {"Nº reg":=^6} {"SO2":=^5} {"CO":=^5} {"NO":=^5} {"NO2":=^5} {"NOx":=^5} {"O3":=^5} {"PM10":=^5}\
 {"PM2.5":=^5} {"PM1":=^5} {"lluv":=^5} {"Temp":=^5} {"VVent":=^5} {"VVmax":=^5} {"TempM":=^5} {"Tempm":=^5}')
for esta in df['NOM_ESTACION'].unique():
 print(f'{esta:26} {df[df["NOM_ESTACION"]==esta]["NOM_ESTACION"].count():6}\
 {df[df["NOM_ESTACION"]==esta]["SO2"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["CO"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["NO"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["NO2"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["NOx"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["O3"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["PM10"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["PM2.5"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["PM1"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["lluvias"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["Temp"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["VelocVent"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["VelocVentMax"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["TempMax"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["TempMin"].isnull().mean()*100:5.2f}')

print(f'{"TOTAL ESTACIONES:":>26} {df["NOM_ESTACION"].count():6}\
{df["SO2"].isnull().mean()*100:5.2f}\
{df["CO"].isnull().mean()*100:5.2f}\
{df["NO"].isnull().mean()*100:5.2f}\
{df["NO2"].isnull().mean()*100:5.2f}\
{df["NOx"].isnull().mean()*100:5.2f}\
{df["O3"].isnull().mean()*100:5.2f}\
{df["PM10"].isnull().mean()*100:5.2f}\
{df["PM2.5"].isnull().mean()*100:5.2f}\
{df["PM1"].isnull().mean()*100:5.2f}\
{df["lluvias"].isnull().mean()*100:5.2f}\
{df["Temp"].isnull().mean()*100:5.2f}\
{df["VelocVent"].isnull().mean()*100:5.2f}\
{df["VelocVentMax"].isnull().mean()*100:5.2f}\
{df["TempMax"].isnull().mean()*100:5.2f}\
{df["TempMin"].isnull().mean()*100:5.2f}')

# %% [markdown]
# **Los resultados de porcentajes obtenidos nos llevan a elegir las estaciones que tienen todos los registros completos y que no superan el 31% en ninguna de las observaciones**
#
# Descartaremos las características CO y PM1 pues en la mayoría de casos supera el 60% de valores nulos.
#
# En cuanto a estaciones descartaremos :
# - Pista de Silla : No contiene todos los registros ( 2191 frente a los 2556).
# - Conselleria METEO : Todos los datos de medición de calidad del aire superan 95% de valores nulos , salvo los meteorológicos
# - Bouleverd Sud : Presenta algún valor con un 100% de NaN
# - Centre : Varias características en el 100% y muy pocos registros ( 730 frente a los 2556 )

# %%
print(f'Nº de registros totales y rango de fechas por estación:')
print(f'{"COD_ESTACION":=^10}{"NOM_ESTACION":=^30} {"Desde":=^10} {"Hasta":=^10} {"Nº reg":=^8}')
for esta in df['NOM_ESTACION'].unique():
  print(f'{str(df[df["NOM_ESTACION"]==esta]["COD_ESTACION"].unique())[0:10]} {esta:30} {str(df[df["NOM_ESTACION"]==esta]["FECHA"].min())[0:10]} {str(df[df["NOM_ESTACION"]==esta]["FECHA"].max())[0:10]} {df[df["NOM_ESTACION"]==esta]["NOM_ESTACION"].count():8}')

# %%
df.drop(['CO'], axis='columns', inplace=True)
df.drop(['PM1'], axis='columns', inplace=True)

# %%
Esta1= df[df["COD_ESTACION"]==46250030].index
df.drop(Esta1, inplace=True)
#df[df["COD_ESTACION"]==46250030]

# %%
Esta1= df[df["COD_ESTACION"]==46250049].index
df.drop(Esta1, inplace=True)
#df[df["COD_ESTACION"]==4625004949]

# %%
Esta1= df[df["COD_ESTACION"]==46250050].index
df.drop(Esta1, inplace=True)
#df[df["COD_ESTACION"]==4625004949]

# %%
Esta1=df[df['COD_ESTACION']==46250054].index
df.drop(Esta1, inplace=True)
#df[df["COD_ESTACION"]==46250030]

# %%
df

# %%
print(f'Nº de registros totales y PORCENTAJE DE atributos nulos por estación:')
print(f'{"NOM_ESTACION":=^26} {"Nº reg":=^6} {"SO2":=^5} {"NO":=^5} {"NO2":=^5} {"NOx":=^5} {"O3":=^5} {"PM10":=^5}\
 {"PM2.5":=^5} {"lluv":=^5} {"Temp":=^5} {"VVent":=^5} {"VVmax":=^5} {"TempM":=^5} {"Tempm":=^5}')
for esta in df['NOM_ESTACION'].unique():
 print(f'{esta:26} {df[df["NOM_ESTACION"]==esta]["NOM_ESTACION"].count():6}\
 {df[df["NOM_ESTACION"]==esta]["SO2"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["NO"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["NO2"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["NOx"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["O3"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["PM10"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["PM2.5"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["lluvias"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["Temp"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["VelocVent"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["VelocVentMax"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["TempMax"].isnull().mean()*100:5.2f}\
 {df[df["NOM_ESTACION"]==esta]["TempMin"].isnull().mean()*100:5.2f}')

print(f'{"TOTAL ESTACIONES:":>26} {df["NOM_ESTACION"].count():6}\
{df["SO2"].isnull().mean()*100:5.2f}\
{df["NO"].isnull().mean()*100:5.2f}\
{df["NO2"].isnull().mean()*100:5.2f}\
{df["NOx"].isnull().mean()*100:5.2f}\
{df["O3"].isnull().mean()*100:5.2f}\
{df["PM10"].isnull().mean()*100:5.2f}\
{df["PM2.5"].isnull().mean()*100:5.2f}\
{df["lluvias"].isnull().mean()*100:5.2f}\
{df["Temp"].isnull().mean()*100:5.2f}\
{df["VelocVent"].isnull().mean()*100:5.2f}\
{df["VelocVentMax"].isnull().mean()*100:5.2f}\
{df["TempMax"].isnull().mean()*100:5.2f}\
{df["TempMin"].isnull().mean()*100:5.2f}')

# %%
df.to_csv('../../datoscsv_write/airWeather_2013-2019_v2.csv', header=True, sep=';', index=False)
