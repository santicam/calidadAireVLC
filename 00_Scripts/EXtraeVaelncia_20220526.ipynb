# %%
import seaborn as sb
import pandas as pd
import numpy as np
import os
import glob

# %%
#Nombre del directorio de datos
PATH = "datoscsv/"
pathname = os.path.join(PATH)
print(pathname)
# Out:
# datoscsv/

# %%
maindf = pd.read_csv(pathname + "SoloVLC_SUCIO.csv",sep=";",decimal=".")
#AirQual_VLC = sb.load_dataset('datoscsv/TodosCSV_SUCIO.csv')
#AirQual_VLC.head()
maindf['COD_ESTACION'] = maindf['COD_ESTACION'].astype(str)
maindf['NOM_ESTACION'] = maindf['NOM_ESTACION'].astype(str)
# Out:
# /tmp/ipykernel_24426/676607684.py:1: DtypeWarning: Columns (11,23,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   maindf = pd.read_csv(pathname + "SoloVLC_SUCIO.csv",sep=";",decimal=".")

# %%
maindf2 = pd.DataFrame()
#maindf2=maindf[maindf.COD_ESTACION.str.contains('462500')]
maindf2 = maindf[maindf.COD_ESTACION.isin(['46250043','46250046','46250047','46250048'])]
maindf2.head()
# Out:
#     COD_ESTACION       NOM_ESTACION       FECHA  SO2   CO   NO   NO2   NOx  \
# 620     46250043  VALÈNCIA - VIVERS  2009-07-01  3.0  0,1  7.0  20.0  31.0
# 621     46250043  VALÈNCIA - VIVERS  2009-07-02  3.0  0,1  3.0  11.0  14.0
# 622     46250043  VALÈNCIA - VIVERS  2009-07-03  3.0  0,2  2.0   6.0   7.0
# 623     46250043  VALÈNCIA - VIVERS  2009-07-04  3.0  0,2  2.0   6.0   8.0
# 624     46250043  VALÈNCIA - VIVERS  2009-07-05  3.0  0,1  2.0   5.0   6.0
#
#        O3 PM10  ... DahA   FA  HCT HMN  HNM H2S  IcdP   Ni    Pb  PST
# 620  54.0  NaN  ...  NaN  NaN  NaN NaN  NaN NaN   NaN  NaN   NaN  NaN
# 621  45.0   31  ...  NaN  NaN  NaN NaN  NaN NaN   NaN    2     0  NaN
# 622  48.0  NaN  ...  NaN  NaN  NaN NaN  NaN NaN   NaN  NaN   NaN  NaN
# 623  39.0   27  ...  NaN  NaN  NaN NaN  NaN NaN   NaN  4,7  0,01  NaN
# 624  41.0   24  ...  NaN  NaN  NaN NaN  NaN NaN   NaN  NaN   NaN  NaN
#
# [5 rows x 44 columns]

# %%
maindf2['COD_ESTACION'].unique()
# Out:
# array(['46250043', '46250046', '46250047', '46250048'], dtype=object)

# %%
maindf2
# Out:
#        COD_ESTACION           NOM_ESTACION       FECHA  SO2   CO    NO   NO2  \
# 620        46250043      VALÈNCIA - VIVERS  2009-07-01  3.0  0,1   7.0  20.0
# 621        46250043      VALÈNCIA - VIVERS  2009-07-02  3.0  0,1   3.0  11.0
# 622        46250043      VALÈNCIA - VIVERS  2009-07-03  3.0  0,2   2.0   6.0
# 623        46250043      VALÈNCIA - VIVERS  2009-07-04  3.0  0,2   2.0   6.0
# 624        46250043      VALÈNCIA - VIVERS  2009-07-05  3.0  0,1   2.0   5.0
# ...             ...                    ...         ...  ...  ...   ...   ...
# 100754     46250046  VALÈNCIA - POLITÈCNIC  2008-10-27  NaN  NaN  29.0  74.0
# 100755     46250046  VALÈNCIA - POLITÈCNIC  2008-10-28  4.0  NaN  30.0  56.0
# 100756     46250046  VALÈNCIA - POLITÈCNIC  2008-10-29  3.0  NaN  15.0  44.0
# 100757     46250046  VALÈNCIA - POLITÈCNIC  2008-10-30  4.0  NaN  11.0  40.0
# 100758     46250046  VALÈNCIA - POLITÈCNIC  2008-10-31  NaN  NaN  24.0  62.0
#
# ...

# %%
maindf2.to_csv('datoscsv/SoloVLC_Principales.csv', header=True, sep=';', index=False)
