# %%
import pandas as pd

# %%
# cargar dataframes

#df = pd.read_csv('datos.csv', delimiter=';')
df = pd.read_csv('AvFrancia.csv', delimiter=',')
#temperaturas = pd.read_csv('temperatura.csv', delimiter=';')
clima = pd.read_csv('clima_2013-2022.csv', delimiter=',')
print('Valores nulos:')
df.isnull().sum()
# Out:
# Valores nulos:
# idEstacion       0
# estacion         0
# FECHA            0
# SO2            362
# CO             392
# PM1           2893
# O3             116
# Veloc.          24
# NO2            438
# NO             438
# PM2.5         1593
# PM10          1593
# NOx            438
# Direc.           3
# HCT           4792
# CH4           4792
# HNM           4792
# dtype: int64

# %%
df
# Out:
#       idEstacion   estacion       FECHA  SO2   CO   PM1    O3  Veloc.   NO2  \
# 0       46250047  AvFrancia  2009-01-01  3.0  0.4  11.0  18.0     1.1  59.0
# 1       46250047  AvFrancia  2009-01-02  3.0  0.5  13.0  13.0     1.1  74.0
# 2       46250047  AvFrancia  2009-01-03  3.0  0.4  12.0  10.0     0.7  70.0
# 3       46250047  AvFrancia  2009-01-04  3.0  0.4   6.0  28.0     1.7  56.0
# 4       46250047  AvFrancia  2009-01-05  3.0  0.4   7.0  16.0     1.0  75.0
# ...          ...        ...         ...  ...  ...   ...   ...     ...   ...
# 4787    46250047  AvFrancia  2022-03-27  4.0  0.1   NaN  91.0     2.0   5.0
# 4788    46250047  AvFrancia  2022-03-28  4.0  0.1   NaN  70.0     NaN  13.0
# 4789    46250047  AvFrancia  2022-03-29  4.0  0.1   NaN  64.0     2.6  13.0
# 4790    46250047  AvFrancia  2022-03-30  4.0  0.1   NaN  59.0     NaN  13.0
# 4791    46250047  AvFrancia  2022-03-31  4.0  0.1   NaN  60.0     1.1   9.0
#
#         NO  PM2.5  PM10    NOx  Direc.  HCT  CH4  HNM
# 0     10.0    NaN   NaN   74.0   196.0  NaN  NaN  NaN
# 1     55.0    NaN   NaN  158.0   193.0  NaN  NaN  NaN
# 2     38.0    NaN   NaN  129.0   142.0  NaN  NaN  NaN
# 3     26.0    NaN   NaN   95.0    78.0  NaN  NaN  NaN
# 4     31.0    NaN   NaN  122.0   182.0  NaN  NaN  NaN
# ...    ...    ...   ...    ...     ...  ...  ...  ...
# 4787   2.0   16.0  46.0    7.0    37.0  NaN  NaN  NaN
# 4788   5.0   19.0  40.0   20.0    40.0  NaN  NaN  NaN
# 4789   6.0   22.0  42.0   22.0    20.0  NaN  NaN  NaN
# 4790   2.0   18.0  44.0   16.0   214.0  NaN  NaN  NaN
# 4791   2.0    5.0  13.0   12.0   294.0  NaN  NaN  NaN
#
# [4792 rows x 17 columns]

# %%
clima
# Out:
#           FECHA   Racha Max (Km/h)  Hora Racha   Veloc (Media)  \
# 0     07-05-2013               41.0    17:50:00           17.0
# 1     08-05-2013               21.0    16:50:00           10.0
# 2     09-05-2013               26.0    14:00:00           11.0
# 3     10-05-2013               31.0    13:20:00           15.0
# 4     11-05-2013               26.0    14:50:00           12.0
# ...          ...                ...         ...            ...
# 3276  26-04-2022               22.0    15:00:00            9.0
# 3277  27-04-2022               20.0    15:30:00           10.0
# 3278  28-04-2022               26.0    16:30:00           13.0
# 3279  29-04-2022               25.0    11:30:00           12.0
# 3280  30-04-2022               26.0    16:40:00           15.0
#
#       Precipitación: l/m2  T. Máxima   T.Mínima
# 0                     0.0        32.1      16.1
# 1                     0.0        29.1      19.8
# 2                     0.0        22.8      17.4
# 3                     0.0        22.3      16.6
# 4                     0.0        21.4      15.1
# ...                   ...         ...       ...
# 3276                  0.0        19.3      10.8
# 3277                  0.5        18.7      13.5
# 3278                  7.9        17.9      14.0
# 3279                  0.0        22.1      11.4
# 3280                  0.1        25.1      14.5
#
# [3281 rows x 7 columns]

# %%
# añadir columna 'TEMP' en df con las temperaturas del segundo dataFrame segun la fecha
#df = pd.merge(left=df, right=temperaturas, how='left', left_on='FECHA', right_on='FECHA')
df = pd.merge(left=df, right=clima, how='left', left_on='FECHA', right_on='FECHA')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7132/2023778874.py in <module>
#       1 # añadir columna 'TEMP' en df con las temperaturas del segundo dataFrame segun la fecha
#       2 #df = pd.merge(left=df, right=temperaturas, how='left', left_on='FECHA', right_on='FECHA')
# ----> 3 df = pd.merge(left=df, right=clima, how='left', left_on='FECHA', right_on='FECHA')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'FECHA'

# %%
df

# %%
# actualizar columna 'Temp.' con 'TEMP' cuando el campo 'Temp.' no tenga valor
df.loc[df['Temp.'].isna(),'Temp.']=df['T. Máxima']

# %%
# una vez hecha la actualización eliminar la columna que sobra
#df = df.drop('TEMP', axis=1)

print('Valores nulos:')
df.isnull().sum()

# %%
df
