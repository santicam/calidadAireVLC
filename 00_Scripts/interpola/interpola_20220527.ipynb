# %%
# este codigo debería integrarse en el script "analizarCorrelacion.ipynb", que es el que leía el CSV(v2) y escribe el CSV(v3)
# además de analizar las posibles correlaciones, al final eliminaba columnas del dataframe que consideramos que no eran significativas
# antes de escribir el CSV(v3)

# %%
# Librerías
import pandas as pd
import numpy as np

# %%
# path = '/content/drive/MyDrive/datoscsv/'
# path local para probar:
path = ''
df = pd.read_csv(path + 'airWeather_2013-2019_v2.csv', sep=';', index_col='FECHA', parse_dates=['FECHA'])

# Recuperar la fecha como campo
df.insert(0, 'FECHA', df.index.strftime('%Y-%m-%d'))
df
# Out:
#                  FECHA  COD_ESTACION            NOM_ESTACION  SO2    NO   NO2  \
# FECHA
# 2013-01-01  2013-01-01      46250043        VALÈNCIA  VIVERS  1.0   5.0  30.0
# 2013-01-02  2013-01-02      46250043        VALÈNCIA  VIVERS  6.0  83.0  85.0
# 2013-01-03  2013-01-03      46250043        VALÈNCIA  VIVERS  3.0  32.0  69.0
# 2013-01-04  2013-01-04      46250043        VALÈNCIA  VIVERS  4.0  50.0  79.0
# 2013-01-05  2013-01-05      46250043        VALÈNCIA  VIVERS  3.0  47.0  75.0
# ...                ...           ...                     ...  ...   ...   ...
# 2019-12-27  2019-12-27      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  21.0  26.0
# 2019-12-28  2019-12-28      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  15.0  23.0
# 2019-12-29  2019-12-29      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0   6.0  18.0
# 2019-12-30  2019-12-30      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  18.0  23.0
# 2019-12-31  2019-12-31      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  12.0  21.0
#
#               NOx    O3  PM10  PM2.5  lluvias   Temp  VelocVent  VelocVentMax  \
# FECHA
# 2013-01-01   39.0  27.0   6.0    5.0      0.0  13.70        0.6           5.5
# 2013-01-02  211.0  16.0  18.0    6.0      0.0  11.40        0.6           3.6
# 2013-01-03  117.0  16.0  18.0   12.0      NaN    NaN        NaN           NaN
# 2013-01-04  156.0  12.0  19.0   13.0      NaN    NaN        NaN           NaN
# 2013-01-05  147.0   9.0  22.0   16.0      NaN    NaN        NaN           NaN
# ...           ...   ...   ...    ...      ...    ...        ...           ...
# 2019-12-27   58.0  16.0  36.0   33.0      0.0  13.55        7.0          14.0
# 2019-12-28   46.0  17.0  40.0   38.0      0.0  10.55        9.0          16.0
# 2019-12-29   27.0  27.0  41.0   40.0      0.0  11.75        8.0          16.0
# 2019-12-30   50.0  21.0  40.0   37.0      0.0   9.90        0.4           3.5
# 2019-12-31   39.0  17.0  39.0   38.0      0.0   8.70        0.3           3.0
#
#            HoraRacha  TempMax  TempMin
# FECHA
# 2013-01-01       NaN     32.1     16.1
# 2013-01-02       NaN     32.1     16.1
# 2013-01-03       NaN      NaN      NaN
# 2013-01-04       NaN      NaN      NaN
# 2013-01-05       NaN      NaN      NaN
# ...              ...      ...      ...
# 2019-12-27  10:00:00     18.7      8.4
# 2019-12-28  06:50:00     15.4      5.7
# 2019-12-29  12:00:00     16.0      7.5
# 2019-12-30       NaN     16.0      7.5
# 2019-12-31       NaN     16.0      7.5
#
# [10224 rows x 17 columns]

# %%
# % de datos faltantes
print ('Antes de interpolar')
df.isnull().sum()/len(df)*100
# Out:
# Antes de interpolar
# FECHA            0.000000
# COD_ESTACION     0.000000
# NOM_ESTACION     0.000000
# SO2              3.834116
# NO               3.599374
# NO2              3.599374
# NOx              3.599374
# O3               1.144366
# PM10            10.524257
# PM2.5           10.944836
# lluvias          5.594679
# Temp             5.594679
# VelocVent        4.176448
# VelocVentMax     5.594679
# HoraRacha        7.824726
# TempMax          5.594679
# TempMin          5.594679
# dtype: float64

# %%
# Interpolar valores faltantes en base a índice de fechas, siempre que el hueco no sea de más de 4 valores NaN

df = df.interpolate(method='time', limit=4, limit_direction='both', limit_area='inside')

# %%
# % de datos faltantes
print ('Después de interpolar')
df.isnull().sum()/len(df)*100
# Out:
# Después de interpolar
# FECHA            0.000000
# COD_ESTACION     0.000000
# NOM_ESTACION     0.000000
# SO2              2.944053
# NO               2.660407
# NO2              2.660407
# NOx              2.660407
# O3               0.831377
# PM10            10.025430
# PM2.5           10.279734
# lluvias          5.281690
# Temp             5.281690
# VelocVent        3.941706
# VelocVentMax     5.281690
# HoraRacha        7.824726
# TempMax          5.281690
# TempMin          5.281690
# dtype: float64

# %%
# Escribir csv depués de interpolar
df.to_csv(path + 'airWeather_2013-2019_v3.csv', header=True, sep=';', index=False)

# %%
df
# Out:
#                  FECHA  COD_ESTACION            NOM_ESTACION  SO2    NO   NO2  \
# FECHA
# 2013-01-01  2013-01-01      46250043        VALÈNCIA  VIVERS  1.0   5.0  30.0
# 2013-01-02  2013-01-02      46250043        VALÈNCIA  VIVERS  6.0  83.0  85.0
# 2013-01-03  2013-01-03      46250043        VALÈNCIA  VIVERS  3.0  32.0  69.0
# 2013-01-04  2013-01-04      46250043        VALÈNCIA  VIVERS  4.0  50.0  79.0
# 2013-01-05  2013-01-05      46250043        VALÈNCIA  VIVERS  3.0  47.0  75.0
# ...                ...           ...                     ...  ...   ...   ...
# 2019-12-27  2019-12-27      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  21.0  26.0
# 2019-12-28  2019-12-28      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  15.0  23.0
# 2019-12-29  2019-12-29      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0   6.0  18.0
# 2019-12-30  2019-12-30      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  18.0  23.0
# 2019-12-31  2019-12-31      46250048  VALÈNCIA  MOLÍ DEL SOL  3.0  12.0  21.0
#
#               NOx    O3  PM10  PM2.5  lluvias       Temp  VelocVent  \
# FECHA
# 2013-01-01   39.0  27.0   6.0    5.0      0.0  13.700000        0.6
# 2013-01-02  211.0  16.0  18.0    6.0      0.0  11.400000        0.6
# 2013-01-03  117.0  16.0  18.0   12.0      0.0  11.438017        0.5
# 2013-01-04  156.0  12.0  19.0   13.0      0.0  11.476033        0.8
# 2013-01-05  147.0   9.0  22.0   16.0      0.0  11.514050        0.4
# ...           ...   ...   ...    ...      ...        ...        ...
# 2019-12-27   58.0  16.0  36.0   33.0      0.0  13.550000        7.0
# 2019-12-28   46.0  17.0  40.0   38.0      0.0  10.550000        9.0
# 2019-12-29   27.0  27.0  41.0   40.0      0.0  11.750000        8.0
# 2019-12-30   50.0  21.0  40.0   37.0      0.0   9.900000        0.4
# 2019-12-31   39.0  17.0  39.0   38.0      0.0   8.700000        0.3
#
#             VelocVentMax HoraRacha  TempMax  TempMin
# FECHA
# 2013-01-01      5.500000       NaN     32.1     16.1
# 2013-01-02      3.600000       NaN     32.1     16.1
# 2013-01-03      3.873183       NaN     32.1     16.1
# 2013-01-04      4.146366       NaN     32.1     16.1
# 2013-01-05      4.419550       NaN     32.1     16.1
# ...                  ...       ...      ...      ...
# 2019-12-27     14.000000  10:00:00     18.7      8.4
# 2019-12-28     16.000000  06:50:00     15.4      5.7
# 2019-12-29     16.000000  12:00:00     16.0      7.5
# 2019-12-30      3.500000       NaN     16.0      7.5
# 2019-12-31      3.000000       NaN     16.0      7.5
#
# [10224 rows x 17 columns]
